# %%
import numpy as np
import random

# Each move is evaluated as to how good it was given the current grid
class Game:

    def __init__(self,grid):
        self.training_history = []
        self.grid = grid
        self.bin_state = 0b00000000000000000000000000

    def check_win(self, grid):
        # Finds the positions of the Xs or Os in the grid
        resX = [np.where(grid == -1), np.where(np.transpose(grid) == -1)]
        resO = [np.where(grid == 1), np.where(np.transpose(grid) == 1)]

        # Gets the coordinates of the places occupied by X or O
        zipX=list(zip(np.where(grid == -1)[0],np.where(grid == -1)[1]))
        zipO=list(zip(np.where(grid == 1)[0],np.where(grid == 1)[1]))

        # Check if the X positions result in a win
        if self._check_row_col(resX):
            return "X WIN"
        # Check if the O positions result in a win
        elif self._check_row_col(resO):
            return "O WIN"
        # Check the diagonals
        elif self._check_diagonals(zipX):
            return "X WIN"
        elif self._check_diagonals(zipO):
            return "O WIN"
        # Check if the board is full
        elif np.where(grid == 0)[0].size == 0:
            # If there are no lines of 3 for XorO and the grid contains no more empty spaces
            return "DRAW"


    # Checks that the positions give a win irrespective of whether it is Os or Xs
    def _check_row_col(self, res):
        for g in res:
            if any(sublist in np.array_str(np.array(g[0])) for sublist in ('0 0 0', '1 1 1','2 2 2')):
                if '0 1 2' in np.array_str(np.array(g[1])):
                    return True

    def _check_diagonals(self, res):
        # the diagonals
        if (0,0) in res and (1,1) in res and (2,2) in res:
            return True
        if (0,2) in res and (1,1) in res and (2,0) in res:
            return True

    # This gets the current grid
    def get_grid(self):
        return self.grid

# %%
import random
import copy
import numpy as np


class Agent:

    def __init__(self):
        pass

    # This returns the location of the position on the grid to place the X or O
    def set_location(self,grid,method, model):
        # Find available positions
        # select a location to place the xoro
        if method == "random":
            select = _get_random_position(grid)
        if method == "neural":
            select = _get_neural_position(grid, model)
        return select

# Static private methods
# Returns the next position of the xoro randomly from the available positions
def _get_random_position(grid):
    # Find positions the contain a 0 (blank)
    available = _get_available_positions(grid)
    return random.choice(available)

# This is where the Neural network goes.
def _get_neural_position(grid, model):
    availableMoves = _get_available_positions(grid)
    maxValue = 0
    bestMove = availableMoves[0]
    for availableMove in availableMoves:
        # get a copy of a board
        boardCopy = copy.deepcopy(grid)
        value = model.predict(boardCopy, 0)
        if value > maxValue:
            maxValue = value
            bestMove = availableMove
    selectedMove = bestMove
    return selectedMove

def _get_available_positions(grid):
    a = np.where(grid == 0)
    return list(zip(a[0], a[1]))

# %%
from keras.layers import Dense
from keras.models import Sequential
from keras.utils import to_categorical
import numpy as np


class TicTacToeModel:

    def __init__(self, numberOfInputs, numberOfOutputs, epochs, batchSize):
        self.epochs = epochs

        self.batchSize = batchSize
        self.numberOfInputs = numberOfInputs
        self.numberOfOutputs = numberOfOutputs
        self.model = Sequential()
        self.model.add(Dense(64, activation='relu', input_shape=(numberOfInputs, )))
        self.model.add(Dense(128, activation='relu'))
        self.model.add(Dense(128, activation='relu'))
        self.model.add(Dense(128, activation='relu'))
        self.model.add(Dense(numberOfOutputs, activation='softmax'))
        self.model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

    def train(self, dataset):
        input = []
        output = []
        for data in dataset:
            input.append(data[1])
            output.append(data[0])

        X = np.array(input).reshape((-1, self.numberOfInputs))
        # X = np.array(input).reshape((len(input), -1))
        y =to_categorical(output, num_classes=3)
        # Train and test data split this gives 80%
        boundary = int(0.8 * len(X))
        X_train = X[:boundary]
        X_test = X[boundary:]
        y_train = y[:boundary]
        y_test = y[boundary:]
        self.model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=self.epochs, batch_size=self.batchSize)
        # self.model.save('OXO_model')
        return self.model


    # This is to use a new model that has been loaded
    def set_model(self, model):
        self.model = model

    def predict(self, data, index):
        return self.model.predict(np.array(data).reshape(-1, self.numberOfInputs))[0][index]
# Out:
# Using TensorFlow backend.

# %%
import copy
from Agent import Agent
from Game import Game
import numpy as np
from Human import Human
from model import TicTacToeModel
import tensorflow as tf

history = []

# Main game loop
def run_game(player1, player2, loaded_model, iterations):
    grid = np.full((3, 3), 0)

    # create the game
    g = Game(grid)
    agent1 = Agent()
    agent2 = Agent()
    human = Human()

    score = 0
    moves = []
    output = 0
    # iterations = 1000
    it = 0
    X_wins = 0
    O_wins = 0
    Draws = 0
    while it < iterations:
        # The moves for each game
        for i in ["X", "O"]:
            while True:
                if i == "X":
                    loc = agent1.set_location(grid,player1,loaded_model)
                    # loc = human.set_location(grid)
                    # Make sure the move is to a blank space before exiting the loop
                    if g.make_move(loc,-1):
                        break
                if i == "O":
                    loc = agent2.set_location(grid,player2,loaded_model)
                    # loc = human.set_location(grid)
                    # Make sure the move is to a blank space before exiting the loop
                    if g.make_move(loc,1):
                        break
            # print(grid)
            res = g.check_win(grid)
            last_state = grid.tolist()
            moves.append(last_state)

            # Goes here if there is a result
            if res:
                print("Game: "+str(it))
                print(res)
                # X wins
                if res[:1] == 'X':
                    X_wins+=1
                    grid = np.full((3, 3), 0)
                    g = Game(grid)
                    output=-1
                # O wins
                elif res[:1] == 'O':
                    O_wins+=1
                    grid = np.full((3, 3), 0)
                    g = Game(grid)
                    output=1
                # Draw
                else:
                    Draws+=1
                    grid = np.full((3, 3), 0)
                    g = Game(grid)
                    output=0
                it += 1
                # If the game is won by less than nine moves then append the last board state to make the array 9 long.
                # Not sure how to make Keras deal with uneven data sizes
                while len(moves) < 9:
                    moves.append(last_state)
                for m in moves:
                    history.append((output,copy.deepcopy(m)))
                moves = []
                break
    return history,X_wins, O_wins, Draws

# %%
from RunGame import run_game
from model import TicTacToeModel


print("--- Summary ---")
history,x,o,d=run_game(player1="random", player2="random", loaded_model=None, iterations=100)
print("X Wins = "+str(x))
print("O Wins = "+str(o))
print("Draws = "+str(d))
# Train the network using the results from the random games
ticTacToeModel = TicTacToeModel(9, 3, 100, 32)
model = ticTacToeModel.train(history)
model.save("OXO_model")
ticTacToeModel.set_model(model)
_, x, o, d = run_game(player1="neural", player2="random", loaded_model=ticTacToeModel, iterations=100)
print("After Learning (Neural = X vs Random = O):")
print("X Wins = "+str(x))
print("O Wins = "+str(o))
print("Draws = "+str(d))
# Out:
# --- Summary ---
# Game: 0
# X WIN
# Game: 1
# X WIN
# Game: 2
# X WIN
# Game: 3
# O WIN
# Game: 4
# X WIN
# Game: 5
# X WIN
# Game: 6
# X WIN
# Game: 7
# O WIN
# Game: 8
# X WIN
# Game: 9
# X WIN
# Game: 10
# X WIN
# Game: 11
# X WIN
# Game: 12
# O WIN
# Game: 13
# DRAW
# Game: 14
# X WIN
# Game: 15
# O WIN
# Game: 16
# X WIN
# Game: 17
# X WIN
# Game: 18
# O WIN
# Game: 19
# X WIN
# Game: 20
# X WIN
# Game: 21
# X WIN
# Game: 22
# O WIN
# Game: 23
# X WIN
# Game: 24
# O WIN
# Game: 25
# O WIN
# Game: 26
# X WIN
# Game: 27
# X WIN
# Game: 28
# X WIN
# Game: 29
# O WIN
# Game: 30
# O WIN
# Game: 31
# X WIN
# Game: 32
# X WIN
# Game: 33
# O WIN
# Game: 34
# DRAW
# Game: 35
# X WIN
# Game: 36
# X WIN
# Game: 37
# O WIN
# Game: 38
# X WIN
# Game: 39
# X WIN
# Game: 40
# O WIN
# Game: 41
# X WIN
# Game: 42
# DRAW
# Game: 43
# O WIN
# Game: 44
# X WIN
# Game: 45
# X WIN
# Game: 46
# X WIN
# Game: 47
# O WIN
# Game: 48
# X WIN
# Game: 49
# O WIN
# Game: 50
# X WIN
# Game: 51
# O WIN
# Game: 52
# O WIN
# Game: 53
# X WIN
# Game: 54
# O WIN
# Game: 55
# DRAW
# Game: 56
# X WIN
# Game: 57
# X WIN
# Game: 58
# X WIN
# Game: 59
# DRAW
# Game: 60
# X WIN
# Game: 61
# O WIN
# Game: 62
# X WIN
# Game: 63
# DRAW
# Game: 64
# O WIN
# Game: 65
# X WIN
# Game: 66
# X WIN
# Game: 67
# X WIN
# Game: 68
# O WIN
# Game: 69
# O WIN
# Game: 70
# X WIN
# Game: 71
# X WIN
# Game: 72
# DRAW
# Game: 73
# X WIN
# Game: 74
# X WIN
# Game: 75
# O WIN
# Game: 76
# O WIN
# Game: 77
# X WIN
# Game: 78
# X WIN
# Game: 79
# DRAW
# Game: 80
# O WIN
# Game: 81
# DRAW
# Game: 82
# X WIN
# Game: 83
# X WIN
# Game: 84
# X WIN
# Game: 85
# X WIN
# Game: 86
# X WIN
# Game: 87
# O WIN
# Game: 88
# X WIN
# Game: 89
# DRAW
# Game: 90
# X WIN
# Game: 91
# X WIN
# Game: 92
# X WIN
# Game: 93
# O WIN
# Game: 94
# O WIN
# Game: 95
# O WIN
# Game: 96
# O WIN
# Game: 97
# O WIN
# Game: 98
# X WIN
# Game: 99
# O WIN
# X Wins = 57
# O Wins = 33
# Draws = 10
# Train on 2160 samples, validate on 540 samples
# Epoch 1/100
# 2160/2160 [==============================] - 0s 94us/step - loss: 0.6510 - accuracy: 0.7329 - val_loss: 0.9255 - val_accuracy: 0.6000
# Epoch 2/100
# 2160/2160 [==============================] - 0s 52us/step - loss: 0.5217 - accuracy: 0.7764 - val_loss: 0.9572 - val_accuracy: 0.6241
# Epoch 3/100
# 2160/2160 [==============================] - 0s 56us/step - loss: 0.4522 - accuracy: 0.8120 - val_loss: 1.0309 - val_accuracy: 0.6000
# Epoch 4/100
# 2160/2160 [==============================] - 0s 53us/step - loss: 0.3982 - accuracy: 0.8384 - val_loss: 1.0478 - val_accuracy: 0.6426
# Epoch 5/100
# 2160/2160 [==============================] - 0s 56us/step - loss: 0.3714 - accuracy: 0.8394 - val_loss: 1.0726 - val_accuracy: 0.5685
# Epoch 6/100
# 2160/2160 [==============================] - 0s 47us/step - loss: 0.3453 - accuracy: 0.8556 - val_loss: 1.1044 - val_accuracy: 0.6333
# Epoch 7/100
# 2160/2160 [==============================] - 0s 43us/step - loss: 0.3262 - accuracy: 0.8648 - val_loss: 1.1553 - val_accuracy: 0.6130
# Epoch 8/100
# 2160/2160 [==============================] - 0s 48us/step - loss: 0.3206 - accuracy: 0.8616 - val_loss: 1.4146 - val_accuracy: 0.5963
# Epoch 9/100
# 2160/2160 [==============================] - 0s 53us/step - loss: 0.3109 - accuracy: 0.8713 - val_loss: 1.1837 - val_accuracy: 0.6333
# Epoch 10/100
# 2160/2160 [==============================] - 0s 49us/step - loss: 0.3010 - accuracy: 0.8778 - val_loss: 1.2381 - val_accuracy: 0.6463
# Epoch 11/100
# 2160/2160 [==============================] - 0s 49us/step - loss: 0.2910 - accuracy: 0.8727 - val_loss: 1.2750 - val_accuracy: 0.6111
# Epoch 12/100
# 2160/2160 [==============================] - 0s 44us/step - loss: 0.2874 - accuracy: 0.8792 - val_loss: 1.3452 - val_accuracy: 0.5759
# Epoch 13/100
# 2160/2160 [==============================] - 0s 47us/step - loss: 0.2744 - accuracy: 0.8815 - val_loss: 1.3814 - val_accuracy: 0.6389
# Epoch 14/100
# 2160/2160 [==============================] - 0s 50us/step - loss: 0.2762 - accuracy: 0.8884 - val_loss: 1.3219 - val_accuracy: 0.6167
# Epoch 15/100
# 2160/2160 [==============================] - 0s 50us/step - loss: 0.2744 - accuracy: 0.8843 - val_loss: 1.3702 - val_accuracy: 0.6241
# Epoch 16/100
# 2160/2160 [==============================] - 0s 49us/step - loss: 0.2614 - accuracy: 0.8870 - val_loss: 1.4015 - val_accuracy: 0.6352
# Epoch 17/100
# 2160/2160 [==============================] - 0s 61us/step - loss: 0.2622 - accuracy: 0.8926 - val_loss: 1.5173 - val_accuracy: 0.6037
# Epoch 18/100
# 2160/2160 [==============================] - 0s 62us/step - loss: 0.2607 - accuracy: 0.8870 - val_loss: 1.4729 - val_accuracy: 0.6148
# Epoch 19/100
# 2160/2160 [==============================] - 0s 59us/step - loss: 0.2520 - accuracy: 0.8954 - val_loss: 1.3642 - val_accuracy: 0.5907
# Epoch 20/100
# 2160/2160 [==============================] - 0s 51us/step - loss: 0.2503 - accuracy: 0.8907 - val_loss: 1.5126 - val_accuracy: 0.6352
# Epoch 21/100
# 2160/2160 [==============================] - 0s 52us/step - loss: 0.2488 - accuracy: 0.8884 - val_loss: 1.5651 - val_accuracy: 0.6370
# Epoch 22/100
# 2160/2160 [==============================] - 0s 46us/step - loss: 0.2485 - accuracy: 0.8935 - val_loss: 1.5303 - val_accuracy: 0.6463
# Epoch 23/100
# 2160/2160 [==============================] - 0s 44us/step - loss: 0.2475 - accuracy: 0.8898 - val_loss: 1.5942 - val_accuracy: 0.6074
# Epoch 24/100
# 2160/2160 [==============================] - 0s 44us/step - loss: 0.2452 - accuracy: 0.8931 - val_loss: 1.5660 - val_accuracy: 0.6056
# Epoch 25/100
# 2160/2160 [==============================] - 0s 44us/step - loss: 0.2414 - accuracy: 0.8940 - val_loss: 1.6587 - val_accuracy: 0.6463
# Epoch 26/100
# 2160/2160 [==============================] - 0s 43us/step - loss: 0.2385 - accuracy: 0.8958 - val_loss: 1.9217 - val_accuracy: 0.6148
# Epoch 27/100
# 2160/2160 [==============================] - 0s 50us/step - loss: 0.2423 - accuracy: 0.8940 - val_loss: 1.7788 - val_accuracy: 0.6074
# Epoch 28/100
# 2160/2160 [==============================] - 0s 50us/step - loss: 0.2368 - accuracy: 0.8958 - val_loss: 1.7894 - val_accuracy: 0.6241
# Epoch 29/100
# 2160/2160 [==============================] - 0s 43us/step - loss: 0.2335 - accuracy: 0.8940 - val_loss: 1.8951 - val_accuracy: 0.6241
# Epoch 30/100
# 2160/2160 [==============================] - 0s 43us/step - loss: 0.2302 - accuracy: 0.8991 - val_loss: 1.7976 - val_accuracy: 0.6389
# Epoch 31/100
# 2160/2160 [==============================] - 0s 52us/step - loss: 0.2313 - accuracy: 0.9019 - val_loss: 1.9226 - val_accuracy: 0.6204
# Epoch 32/100
# 2160/2160 [==============================] - 0s 44us/step - loss: 0.2276 - accuracy: 0.8981 - val_loss: 1.7950 - val_accuracy: 0.6093
# Epoch 33/100
# 2160/2160 [==============================] - 0s 46us/step - loss: 0.2287 - accuracy: 0.8963 - val_loss: 1.9162 - val_accuracy: 0.6000
# Epoch 34/100
# 2160/2160 [==============================] - 0s 46us/step - loss: 0.2290 - accuracy: 0.8977 - val_loss: 2.0938 - val_accuracy: 0.6278
# Epoch 35/100
# 2160/2160 [==============================] - 0s 42us/step - loss: 0.2284 - accuracy: 0.8972 - val_loss: 1.8798 - val_accuracy: 0.5963
# Epoch 36/100
# 2160/2160 [==============================] - 0s 41us/step - loss: 0.2257 - accuracy: 0.8986 - val_loss: 1.9289 - val_accuracy: 0.6259
# Epoch 37/100
# 2160/2160 [==============================] - 0s 52us/step - loss: 0.2261 - accuracy: 0.8981 - val_loss: 1.9717 - val_accuracy: 0.6130
# Epoch 38/100
# 2160/2160 [==============================] - 0s 46us/step - loss: 0.2264 - accuracy: 0.8972 - val_loss: 1.9647 - val_accuracy: 0.5926
# Epoch 39/100
# 2160/2160 [==============================] - 0s 46us/step - loss: 0.2193 - accuracy: 0.8963 - val_loss: 2.3175 - val_accuracy: 0.6093
# Epoch 40/100
# 2160/2160 [==============================] - 0s 43us/step - loss: 0.2238 - accuracy: 0.8995 - val_loss: 2.2902 - val_accuracy: 0.6056
# Epoch 41/100
# 2160/2160 [==============================] - 0s 54us/step - loss: 0.2243 - accuracy: 0.8977 - val_loss: 2.2996 - val_accuracy: 0.6056
# Epoch 42/100
# 2160/2160 [==============================] - 0s 48us/step - loss: 0.2234 - accuracy: 0.8981 - val_loss: 2.3300 - val_accuracy: 0.6204
# Epoch 43/100
# 2160/2160 [==============================] - 0s 53us/step - loss: 0.2242 - accuracy: 0.8995 - val_loss: 2.5543 - val_accuracy: 0.5926
# Epoch 44/100
# 2160/2160 [==============================] - 0s 52us/step - loss: 0.2168 - accuracy: 0.9005 - val_loss: 2.6797 - val_accuracy: 0.6185
# Epoch 45/100
# 2160/2160 [==============================] - 0s 43us/step - loss: 0.2202 - accuracy: 0.9051 - val_loss: 2.5800 - val_accuracy: 0.6019
# Epoch 46/100
# 2160/2160 [==============================] - 0s 44us/step - loss: 0.2164 - accuracy: 0.8968 - val_loss: 2.6821 - val_accuracy: 0.6037
# Epoch 47/100
# 2160/2160 [==============================] - 0s 48us/step - loss: 0.2150 - accuracy: 0.9023 - val_loss: 3.0477 - val_accuracy: 0.6259
# Epoch 48/100
# 2160/2160 [==============================] - 0s 46us/step - loss: 0.2161 - accuracy: 0.9005 - val_loss: 2.8305 - val_accuracy: 0.6093
# Epoch 49/100
# 2160/2160 [==============================] - 0s 38us/step - loss: 0.2175 - accuracy: 0.9032 - val_loss: 3.2376 - val_accuracy: 0.6111
# Epoch 50/100
# 2160/2160 [==============================] - 0s 45us/step - loss: 0.2150 - accuracy: 0.9000 - val_loss: 3.0053 - val_accuracy: 0.6167
# Epoch 51/100
# 2160/2160 [==============================] - 0s 51us/step - loss: 0.2156 - accuracy: 0.9000 - val_loss: 3.0001 - val_accuracy: 0.6315
# Epoch 52/100
# 2160/2160 [==============================] - 0s 44us/step - loss: 0.2109 - accuracy: 0.9046 - val_loss: 3.8676 - val_accuracy: 0.6241
# Epoch 53/100
# 2160/2160 [==============================] - 0s 42us/step - loss: 0.2161 - accuracy: 0.9005 - val_loss: 3.5363 - val_accuracy: 0.5907
# Epoch 54/100
# 2160/2160 [==============================] - 0s 46us/step - loss: 0.2137 - accuracy: 0.8995 - val_loss: 3.6694 - val_accuracy: 0.6111
# Epoch 55/100
# 2160/2160 [==============================] - 0s 47us/step - loss: 0.2165 - accuracy: 0.9009 - val_loss: 3.3203 - val_accuracy: 0.5981
# Epoch 56/100
# 2160/2160 [==============================] - 0s 39us/step - loss: 0.2119 - accuracy: 0.9009 - val_loss: 3.9280 - val_accuracy: 0.5944
# Epoch 57/100
# 2160/2160 [==============================] - 0s 50us/step - loss: 0.2110 - accuracy: 0.8995 - val_loss: 3.8349 - val_accuracy: 0.6185
# Epoch 58/100
# 2160/2160 [==============================] - 0s 57us/step - loss: 0.2090 - accuracy: 0.9042 - val_loss: 3.5340 - val_accuracy: 0.5963
# Epoch 59/100
# 2160/2160 [==============================] - 0s 47us/step - loss: 0.2091 - accuracy: 0.9032 - val_loss: 4.2724 - val_accuracy: 0.5926
# Epoch 60/100
# 2160/2160 [==============================] - 0s 39us/step - loss: 0.2107 - accuracy: 0.9046 - val_loss: 3.8706 - val_accuracy: 0.6204
# Epoch 61/100
# 2160/2160 [==============================] - 0s 41us/step - loss: 0.2118 - accuracy: 0.9028 - val_loss: 3.4189 - val_accuracy: 0.6185
# Epoch 62/100
# 2160/2160 [==============================] - 0s 37us/step - loss: 0.2139 - accuracy: 0.8991 - val_loss: 3.9652 - val_accuracy: 0.5944
# Epoch 63/100
# 2160/2160 [==============================] - 0s 43us/step - loss: 0.2099 - accuracy: 0.9046 - val_loss: 4.2974 - val_accuracy: 0.6130
# Epoch 64/100
# 2160/2160 [==============================] - 0s 45us/step - loss: 0.2100 - accuracy: 0.9009 - val_loss: 4.0510 - val_accuracy: 0.6019
# Epoch 65/100
# 2160/2160 [==============================] - 0s 43us/step - loss: 0.2153 - accuracy: 0.9005 - val_loss: 4.1239 - val_accuracy: 0.6148
# Epoch 66/100
# 2160/2160 [==============================] - 0s 41us/step - loss: 0.2069 - accuracy: 0.9042 - val_loss: 4.2059 - val_accuracy: 0.6093
# Epoch 67/100
# 2160/2160 [==============================] - 0s 47us/step - loss: 0.2087 - accuracy: 0.9028 - val_loss: 4.1664 - val_accuracy: 0.6019
# Epoch 68/100
# 2160/2160 [==============================] - 0s 53us/step - loss: 0.2103 - accuracy: 0.9042 - val_loss: 4.3505 - val_accuracy: 0.6093
# Epoch 69/100
# 2160/2160 [==============================] - 0s 48us/step - loss: 0.2107 - accuracy: 0.9060 - val_loss: 4.6471 - val_accuracy: 0.5963
# Epoch 70/100
# 2160/2160 [==============================] - 0s 47us/step - loss: 0.2095 - accuracy: 0.9019 - val_loss: 4.3331 - val_accuracy: 0.6056
# Epoch 71/100
# 2160/2160 [==============================] - 0s 45us/step - loss: 0.2071 - accuracy: 0.9019 - val_loss: 4.5996 - val_accuracy: 0.6204
# Epoch 72/100
# 2160/2160 [==============================] - 0s 45us/step - loss: 0.2148 - accuracy: 0.9014 - val_loss: 4.9361 - val_accuracy: 0.6111
# Epoch 73/100
# 2160/2160 [==============================] - 0s 42us/step - loss: 0.2067 - accuracy: 0.9023 - val_loss: 4.8416 - val_accuracy: 0.5963
# Epoch 74/100
# 2160/2160 [==============================] - 0s 59us/step - loss: 0.2057 - accuracy: 0.9056 - val_loss: 5.0077 - val_accuracy: 0.6111
# Epoch 75/100
# 2160/2160 [==============================] - 0s 41us/step - loss: 0.2172 - accuracy: 0.9000 - val_loss: 5.0031 - val_accuracy: 0.6074
# Epoch 76/100
# 2160/2160 [==============================] - 0s 45us/step - loss: 0.2099 - accuracy: 0.9051 - val_loss: 5.0367 - val_accuracy: 0.6093
# Epoch 77/100
# 2160/2160 [==============================] - 0s 41us/step - loss: 0.2074 - accuracy: 0.9023 - val_loss: 5.3436 - val_accuracy: 0.6148
# Epoch 78/100
# 2160/2160 [==============================] - 0s 41us/step - loss: 0.2078 - accuracy: 0.9019 - val_loss: 5.4817 - val_accuracy: 0.5944
# Epoch 79/100
# 2160/2160 [==============================] - 0s 45us/step - loss: 0.2056 - accuracy: 0.9019 - val_loss: 6.3859 - val_accuracy: 0.6204
# Epoch 80/100
# 2160/2160 [==============================] - 0s 42us/step - loss: 0.2127 - accuracy: 0.9074 - val_loss: 5.6652 - val_accuracy: 0.6167
# Epoch 81/100
# 2160/2160 [==============================] - 0s 40us/step - loss: 0.2103 - accuracy: 0.9023 - val_loss: 5.5257 - val_accuracy: 0.6093
# Epoch 82/100
# 2160/2160 [==============================] - 0s 53us/step - loss: 0.2081 - accuracy: 0.9060 - val_loss: 5.4806 - val_accuracy: 0.6130
# Epoch 83/100
# 2160/2160 [==============================] - 0s 44us/step - loss: 0.2177 - accuracy: 0.9019 - val_loss: 5.3367 - val_accuracy: 0.6296
# Epoch 84/100
# 2160/2160 [==============================] - 0s 44us/step - loss: 0.2024 - accuracy: 0.9074 - val_loss: 5.8077 - val_accuracy: 0.6204
# Epoch 85/100
# 2160/2160 [==============================] - 0s 41us/step - loss: 0.2097 - accuracy: 0.9051 - val_loss: 5.5214 - val_accuracy: 0.6000
# Epoch 86/100
# 2160/2160 [==============================] - 0s 48us/step - loss: 0.2078 - accuracy: 0.9042 - val_loss: 6.4947 - val_accuracy: 0.5889
# Epoch 87/100
# 2160/2160 [==============================] - 0s 39us/step - loss: 0.2039 - accuracy: 0.9069 - val_loss: 5.6786 - val_accuracy: 0.6093
# Epoch 88/100
# 2160/2160 [==============================] - 0s 43us/step - loss: 0.2157 - accuracy: 0.9037 - val_loss: 5.7009 - val_accuracy: 0.6000
# Epoch 89/100
# 2160/2160 [==============================] - 0s 39us/step - loss: 0.2085 - accuracy: 0.9032 - val_loss: 6.0124 - val_accuracy: 0.6148
# Epoch 90/100
# 2160/2160 [==============================] - 0s 40us/step - loss: 0.2033 - accuracy: 0.9051 - val_loss: 6.6330 - val_accuracy: 0.5926
# Epoch 91/100
# 2160/2160 [==============================] - 0s 40us/step - loss: 0.2120 - accuracy: 0.9046 - val_loss: 6.3689 - val_accuracy: 0.6315
# Epoch 92/100
# 2160/2160 [==============================] - 0s 42us/step - loss: 0.2193 - accuracy: 0.9019 - val_loss: 6.2407 - val_accuracy: 0.6222
# Epoch 93/100
# 2160/2160 [==============================] - 0s 43us/step - loss: 0.2068 - accuracy: 0.8991 - val_loss: 5.9727 - val_accuracy: 0.6130
# Epoch 94/100
# 2160/2160 [==============================] - 0s 40us/step - loss: 0.2168 - accuracy: 0.9014 - val_loss: 5.9317 - val_accuracy: 0.6037
# Epoch 95/100
# 2160/2160 [==============================] - 0s 40us/step - loss: 0.2031 - accuracy: 0.9069 - val_loss: 7.1180 - val_accuracy: 0.6222
# Epoch 96/100
# 2160/2160 [==============================] - 0s 42us/step - loss: 0.2034 - accuracy: 0.9069 - val_loss: 6.5963 - val_accuracy: 0.6167
# Epoch 97/100
# 2160/2160 [==============================] - 0s 50us/step - loss: 0.2169 - accuracy: 0.9014 - val_loss: 5.9601 - val_accuracy: 0.6167
# Epoch 98/100
# 2160/2160 [==============================] - 0s 41us/step - loss: 0.2086 - accuracy: 0.9042 - val_loss: 6.5470 - val_accuracy: 0.6148
# Epoch 99/100
# 2160/2160 [==============================] - 0s 39us/step - loss: 0.2145 - accuracy: 0.9042 - val_loss: 6.2559 - val_accuracy: 0.6130
# Epoch 100/100
# 2160/2160 [==============================] - 0s 47us/step - loss: 0.2068 - accuracy: 0.9037 - val_loss: 7.1562 - val_accuracy: 0.6056
# Game: 0
# X WIN
# Game: 1
# X WIN
# Game: 2
# O WIN
# Game: 3
# O WIN
# Game: 4
# DRAW
# Game: 5
# X WIN
# Game: 6
# X WIN
# Game: 7
# X WIN
# Game: 8
# X WIN
# Game: 9
# X WIN
# Game: 10
# X WIN
# Game: 11
# X WIN
# Game: 12
# X WIN
# Game: 13
# O WIN
# Game: 14
# O WIN
# Game: 15
# X WIN
# Game: 16
# X WIN
# Game: 17
# X WIN
# Game: 18
# X WIN
# Game: 19
# X WIN
# Game: 20
# O WIN
# Game: 21
# X WIN
# Game: 22
# X WIN
# Game: 23
# X WIN
# Game: 24
# X WIN
# Game: 25
# O WIN
# Game: 26
# X WIN
# Game: 27
# X WIN
# Game: 28
# X WIN
# Game: 29
# O WIN
# Game: 30
# X WIN
# Game: 31
# X WIN
# Game: 32
# O WIN
# Game: 33
# O WIN
# Game: 34
# X WIN
# Game: 35
# X WIN
# Game: 36
# X WIN
# Game: 37
# X WIN
# Game: 38
# X WIN
# Game: 39
# X WIN
# Game: 40
# X WIN
# Game: 41
# X WIN
# Game: 42
# O WIN
# Game: 43
# X WIN
# Game: 44
# X WIN
# Game: 45
# X WIN
# Game: 46
# X WIN
# Game: 47
# X WIN
# Game: 48
# X WIN
# Game: 49
# O WIN
# Game: 50
# O WIN
# Game: 51
# X WIN
# Game: 52
# X WIN
# Game: 53
# O WIN
# Game: 54
# X WIN
# Game: 55
# X WIN
# Game: 56
# X WIN
# Game: 57
# X WIN
# Game: 58
# X WIN
# Game: 59
# X WIN
# Game: 60
# X WIN
# Game: 61
# O WIN
# Game: 62
# X WIN
# Game: 63
# O WIN
# Game: 64
# X WIN
# Game: 65
# X WIN
# Game: 66
# X WIN
# Game: 67
# X WIN
# Game: 68
# X WIN
# Game: 69
# DRAW
# Game: 70
# DRAW
# Game: 71
# X WIN
# Game: 72
# X WIN
# Game: 73
# X WIN
# Game: 74
# X WIN
# Game: 75
# X WIN
# Game: 76
# X WIN
# Game: 77
# X WIN
# Game: 78
# X WIN
# Game: 79
# X WIN
# Game: 80
# X WIN
# Game: 81
# X WIN
# Game: 82
# X WIN
# Game: 83
# DRAW
# Game: 84
# DRAW
# Game: 85
# O WIN
# Game: 86
# X WIN
# Game: 87
# X WIN
# Game: 88
# X WIN
# Game: 89
# X WIN
# Game: 90
# X WIN
# Game: 91
# X WIN
# Game: 92
# X WIN
# Game: 93
# O WIN
# Game: 94
# X WIN
# Game: 95
# X WIN
# Game: 96
# O WIN
# Game: 97
# X WIN
# Game: 98
# X WIN
# Game: 99
# X WIN
# After Learning (Neural = X vs Random = O):
# X Wins = 77
# O Wins = 18
# Draws = 5

# %%
import tensorflow as tf
from RunGame import run_game
from model import TicTacToeModel

ticTacToeModel = TicTacToeModel(9, 3, 100, 32)

# Get the model from the saved file
loaded_model = tf.keras.models.load_model("OXO_model")

# Set the model to use in the game to be the one just loaded
ticTacToeModel.set_model(loaded_model)
_ x, o, d = run_game(player1="neural", player2="random", loaded_model=ticTacToeModel, iterations=100)

print("After Learning (Neural = X vs Random = O):")
print("X Wins = "+str(x))
print("O Wins = "+str(o))
print("Draws = "+str(d))
# Out:
# Game: 0
# X WIN
# Game: 1
# X WIN
# Game: 2
# X WIN
# Game: 3
# X WIN
# Game: 4
# X WIN
# Game: 5
# X WIN
# Game: 6
# X WIN
# Game: 7
# X WIN
# Game: 8
# X WIN
# Game: 9
# O WIN
# Game: 10
# O WIN
# Game: 11
# X WIN
# Game: 12
# X WIN
# Game: 13
# X WIN
# Game: 14
# X WIN
# Game: 15
# X WIN
# Game: 16
# X WIN
# Game: 17
# X WIN
# Game: 18
# X WIN
# Game: 19
# X WIN
# Game: 20
# X WIN
# Game: 21
# DRAW
# Game: 22
# X WIN
# Game: 23
# X WIN
# Game: 24
# X WIN
# Game: 25
# O WIN
# Game: 26
# X WIN
# Game: 27
# X WIN
# Game: 28
# O WIN
# Game: 29
# X WIN
# Game: 30
# X WIN
# Game: 31
# X WIN
# Game: 32
# X WIN
# Game: 33
# X WIN
# Game: 34
# X WIN
# Game: 35
# O WIN
# Game: 36
# X WIN
# Game: 37
# X WIN
# Game: 38
# X WIN
# Game: 39
# X WIN
# Game: 40
# O WIN
# Game: 41
# X WIN
# Game: 42
# X WIN
# Game: 43
# O WIN
# Game: 44
# X WIN
# Game: 45
# O WIN
# Game: 46
# X WIN
# Game: 47
# X WIN
# Game: 48
# X WIN
# Game: 49
# O WIN
# Game: 50
# X WIN
# Game: 51
# X WIN
# Game: 52
# X WIN
# Game: 53
# X WIN
# Game: 54
# O WIN
# Game: 55
# X WIN
# Game: 56
# O WIN
# Game: 57
# X WIN
# Game: 58
# X WIN
# Game: 59
# X WIN
# Game: 60
# X WIN
# Game: 61
# X WIN
# Game: 62
# X WIN
# Game: 63
# O WIN
# Game: 64
# O WIN
# Game: 65
# X WIN
# Game: 66
# X WIN
# Game: 67
# X WIN
# Game: 68
# X WIN
# Game: 69
# X WIN
# Game: 70
# X WIN
# Game: 71
# X WIN
# Game: 72
# X WIN
# Game: 73
# X WIN
# Game: 74
# X WIN
# Game: 75
# O WIN
# Game: 76
# X WIN
# Game: 77
# X WIN
# Game: 78
# X WIN
# Game: 79
# X WIN
# Game: 80
# X WIN
# Game: 81
# X WIN
# Game: 82
# O WIN
# Game: 83
# X WIN
# Game: 84
# X WIN
# Game: 85
# X WIN
# Game: 86
# O WIN
# Game: 87
# X WIN
# Game: 88
# X WIN
# Game: 89
# X WIN
# Game: 90
# X WIN
# Game: 91
# X WIN
# Game: 92
# O WIN
# Game: 93
# X WIN
# Game: 94
# X WIN
# Game: 95
# X WIN
# Game: 96
# X WIN
# Game: 97
# X WIN
# Game: 98
# X WIN
# Game: 99
# X WIN
